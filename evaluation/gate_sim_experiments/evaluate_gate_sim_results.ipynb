# %% [markdown]
# ## Install Dependencies

# %%
# %pip install matplotlib

import numpy as np
from matplotlib import pyplot as plt
from statistics import mean, median
# Out:
# Requirement already satisfied: matplotlib in /Users/christophstein/Documents/jku/quapsim/venv/lib/python3.13/site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/christophstein/Documents/jku/quapsim/venv/lib/python3.13/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/christophstein/Documents/jku/quapsim/venv/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/christophstein/Documents/jku/quapsim/venv/lib/python3.13/site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/christophstein/Documents/jku/quapsim/venv/lib/python3.13/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /Users/christophstein/Documents/jku/quapsim/venv/lib/python3.13/site-packages (from matplotlib) (2.2.0)
# Requirement already satisfied: packaging>=20.0 in /Users/christophstein/Documents/jku/quapsim/venv/lib/python3.13/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /Users/christophstein/Documents/jku/quapsim/venv/lib/python3.13/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/christophstein/Documents/jku/quapsim/venv/lib/python3.13/site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/christophstein/Documents/jku/quapsim/venv/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/christophstein/Documents/jku/quapsim/venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 25.0 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
plt.rcParams["figure.dpi"] = 300

# %%
def printb(text: str) -> None:
    print("\033[1m" + text + "\033[0m")

# %% [markdown]
# ## Load result data

# %%
import json 

with open("experiment_gate_sim_results.json", "r") as results_file:
    experiments = json.load(results_file)

# %%
qubit_nums = list(experiments.keys())
print(f"Available qubit nums: {qubit_nums}")
# Out:
# Available qubit nums: ['3', '4', '5', '6', '7', '8']

# %%
target_dir = "results" # Used for storing plots

# %% [markdown]
# ## Create Plots for Simulation Duration per Gate

# %%
for qubit_num in qubit_nums:
    sel_experiment = experiments[qubit_num]

    gate_names = list(sel_experiment.keys())
    gate_names.sort()

    durations = []

    for gate_name in gate_names:

        gate_durations = sel_experiment[gate_name]
        durations.append(gate_durations)

    fig, ax = plt.subplots()

    ax.boxplot(durations, showfliers=False)

    ax.set_xlabel("gate name")
    ax.set_ylabel("simulation duration")
    ax.set_ylim(0)

    plt.xticks([i + 1 for i in range(len(gate_names))], gate_names, fontsize=7, rotation=45)

    printb(f"Simulation durations of gates for {qubit_num} qubits:")

    plt.grid()

    plt.savefig(f"{target_dir}/gate_sim_{qubit_num}q.png", bbox_inches='tight')
    plt.show()
# Out:
# Simulation durations of gates for 3 qubits:
# Simulation durations of gates for 4 qubits:
# Simulation durations of gates for 5 qubits:
# Simulation durations of gates for 6 qubits:
# Simulation durations of gates for 7 qubits:
# Simulation durations of gates for 8 qubits:

# %%
for qubit_num in qubit_nums:
    sel_experiment = experiments[qubit_num]

    gate_names = list(sel_experiment.keys())
    gate_names.sort()

    sample_counts = [
        len(sel_experiment[gate_name]) for gate_name in gate_names
    ]

    fig, ax = plt.subplots()

    ax.plot([i + 1 for i in range(len(gate_names))], sample_counts)

    ax.set_xlabel("gate name")
    ax.set_ylabel("sample size")
    ax.set_ylim(0)

    plt.xticks([i + 1 for i in range(len(gate_names))], gate_names, fontsize=7, rotation=45)

    printb(f"Sample count of each gate for {qubit_num} qubits:")

    plt.grid()

    # plt.savefig(f"{target_dir}/gate_sim_{qubit_num}q.png")
    plt.show()
# Out:
# Sample count of each gate for 3 qubits:
# Sample count of each gate for 4 qubits:
# Sample count of each gate for 5 qubits:
# Sample count of each gate for 6 qubits:
# Sample count of each gate for 7 qubits:
# Sample count of each gate for 8 qubits:
